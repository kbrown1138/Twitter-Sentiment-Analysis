# %% [markdown]
# # Twitter Sentiment Analysis
# * On 10/06/18 each news source's overall Twitter sentiment was positive.
# * Both the BBC and New York Times accounts had the same overall sentiment level at this particular time.
# * A good amount of tweets tend to have zero polarity, which may indicate more objective and less biased reports.

# %%
# Import Dependencies
import tweepy
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from config import consumer_key, consumer_secret, access_token, access_token_secret
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Output File (CSV)
output_data_file = "sentiments.csv"

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target User Account
target_user = "@BBC"

# Counter
counter = 1

# Variables for holding sentiments
sentiments_bbc = []

# Create variable for holding the oldest tweet
oldest_tweet = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):
    
    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user, max_id = oldest_tweet)
    
    # Loop through all tweets 
    for tweet in public_tweets:
    
        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
    
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments_bbc.append({"Source": tweet["user"]["name"],
                                "Text": tweet["text"],
                                "Date": tweet["created_at"], 
                                "Compound": compound,
                                "Positive": pos,
                                "Negative": neu,
                                "Neutral": neg, 
                                "Tweets Ago": counter})
        
        # Add to counter
        counter += 1

# Convert sentiments to DataFrame
sentiments_bbc_pd = pd.DataFrame.from_dict(sentiments_bbc)

# Display DataFrame
sentiments_bbc_pd.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.0000  Sat Oct 06 15:32:00 +0000 2018     1.000    0.000     0.000
# 1   -0.4189  Sat Oct 06 15:11:07 +0000 2018     0.709    0.200     0.091
# 2    0.0000  Sat Oct 06 14:06:03 +0000 2018     1.000    0.000     0.000
# 3   -0.4939  Sat Oct 06 13:10:02 +0000 2018     0.789    0.211     0.000
# 4   -0.4588  Sat Oct 06 12:08:01 +0000 2018     0.769    0.231     0.000
#
#   Source                                               Text  Tweets Ago
# 0    BBC  These caves in rural Italy have been transform...           1
# 1    BBC  Please can everyone stop drinking their own ur...           2
# 2    BBC  Going, going, gone!\n\nA Banksy artwork shredd...           3
# 3    BBC  ❤️ George Shelley opens up about grief and how...           4
# 4    BBC  Footage shows hundreds of tents abandoned by p...           5

# %%
# Target User Account
target_user = "@CBS"

# Counter
counter = 1

# Variables for holding sentiments
sentiments_cbs = []

# Create variable for holding the oldest tweet
oldest_tweet = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):
    
    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user, max_id = oldest_tweet)
    
    # Loop through all tweets 
    for tweet in public_tweets:
    
        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
    
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments_cbs.append({"Source": tweet["user"]["name"],
                               "Text": tweet["text"],
                                "Date": tweet["created_at"], 
                                "Compound": compound,
                                "Positive": pos,
                                "Negative": neu,
                                "Neutral": neg, 
                                "Tweets Ago": counter})
        
        # Add to counter
        counter += 1

# Convert sentiments to DataFrame
sentiments_cbs_pd = pd.DataFrame.from_dict(sentiments_cbs)

# Display DataFrame
sentiments_cbs_pd.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.5423  Fri Oct 05 23:30:00 +0000 2018     0.800    0.000     0.200
# 1   -0.3612  Fri Oct 05 20:10:09 +0000 2018     0.821    0.179     0.000
# 2    0.0000  Fri Oct 05 19:23:53 +0000 2018     1.000    0.000     0.000
# 3   -0.6808  Fri Oct 05 17:42:12 +0000 2018     0.811    0.189     0.000
# 4    0.5023  Fri Oct 05 16:45:23 +0000 2018     0.787    0.000     0.213
#
#   Source                                               Text  Tweets Ago
# 0    CBS  Viewers in Atlanta, Charlotte, Pittsburgh, and...           1
# 1    CBS  RT @MadamSecretary: Worlds collide when former...           2
# 2    CBS  .@TheNeighborhood's @BethBehrs and @latelatesh...           3
# 3    CBS  RT @FBICBS: When a killer's victim survives to...           4
# 4    CBS  But you know the CBS Fall TV that makes YOU sm...           5

# %%
# Target User Account
target_user = "@CNN"

# Counter
counter = 1

# Variables for holding sentiments
sentiments_cnn = []

# Create variable for holding the oldest tweet
oldest_tweet = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):
    
    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user, max_id = oldest_tweet)
    
    # Loop through all tweets 
    for tweet in public_tweets:
    
        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
    
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments_cnn.append({"Source": tweet["user"]["name"],
                               "Text": tweet["text"],
                                "Date": tweet["created_at"], 
                                "Compound": compound,
                                "Positive": pos,
                                "Negative": neu,
                                "Neutral": neg, 
                                "Tweets Ago": counter})
        
        # Add to counter
        counter += 1

# Convert sentiments to DataFrame
sentiments_cnn_pd = pd.DataFrame.from_dict(sentiments_cnn)

# Display DataFrame
sentiments_cnn_pd.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.0000  Sat Oct 06 15:30:14 +0000 2018      1.00    0.000     0.000
# 1    0.0000  Sat Oct 06 15:11:44 +0000 2018      1.00    0.000     0.000
# 2    0.0000  Sat Oct 06 15:00:47 +0000 2018      1.00    0.000     0.000
# 3    0.0000  Sat Oct 06 14:50:14 +0000 2018      1.00    0.000     0.000
# 4   -0.4019  Sat Oct 06 14:38:57 +0000 2018      0.57    0.247     0.183
#
#   Source                                               Text  Tweets Ago
# 0    CNN  First lady Melania Trump: "Glad" both Brett Ka...           1
# 1    CNN  How Casper drove Mattress Firm into bankruptcy...           2
# 2    CNN  Interpol says it has asked Chinese authorities...           3
# 3    CNN  Where women are turning toward Democrats. And ...           4
# 4    CNN  Eating processed meats like bacon, sausages an...           5

# %%
# Target User Account
target_user = "@FoxNews"

# Counter
counter = 1

# Variables for holding sentiments
sentiments_fox = []

# Create variable for holding the oldest tweet
oldest_tweet = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):
    
    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user, max_id = oldest_tweet)
    
    # Loop through all tweets 
    for tweet in public_tweets:
    
        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
    
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments_fox.append({"Source": tweet["user"]["name"],
                               "Text": tweet["text"],
                                "Date": tweet["created_at"], 
                                "Compound": compound,
                                "Positive": pos,
                                "Negative": neu,
                                "Neutral": neg, 
                                "Tweets Ago": counter})
        
        # Add to counter
        counter += 1

# Convert sentiments to DataFrame
sentiments_fox_pd = pd.DataFrame.from_dict(sentiments_fox)

# Display DataFrame
sentiments_fox_pd.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.5994  Sat Oct 06 15:25:00 +0000 2018     0.766      0.0     0.234
# 1    0.0000  Sat Oct 06 15:09:21 +0000 2018     1.000      0.0     0.000
# 2    0.5574  Sat Oct 06 14:58:10 +0000 2018     0.806      0.0     0.194
# 3    0.0000  Sat Oct 06 14:53:45 +0000 2018     1.000      0.0     0.000
# 4    0.4404  Sat Oct 06 14:44:41 +0000 2018     0.868      0.0     0.132
#
#      Source                                               Text  Tweets Ago
# 0  Fox News  TODAY: Watch special coverage of the Kavanaugh...           1
# 1  Fox News  Banksy’s painting self-destructs moments after...           2
# 2  Fox News  U.S. Senators make remarks about the nominatio...           3
# 3  Fox News  .@lisamurkowski to vote ‘present’ on Kavanaugh...           4
# 4  Fox News  Mark Penn: “I hope as part of the postmortem o...           5

# %%
# Target User Account
target_user = "@nytimes"

# Counter
counter = 1

# Variables for holding sentiments
sentiments_nytimes = []

# Create variable for holding the oldest tweet
oldest_tweet = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):
    
    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user, max_id = oldest_tweet)
    
    # Loop through all tweets 
    for tweet in public_tweets:
    
        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
    
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments_nytimes.append({"Source": tweet["user"]["name"],
                                   "Text": tweet["text"],
                                    "Date": tweet["created_at"], 
                                    "Compound": compound,
                                    "Positive": pos,
                                    "Negative": neu,
                                    "Neutral": neg, 
                                    "Tweets Ago": counter})
        
        # Add to counter
        counter += 1

        # Convert sentiments to DataFrame
sentiments_nytimes_pd = pd.DataFrame.from_dict(sentiments_nytimes)

# Display DataFrame
sentiments_nytimes_pd.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0   -0.3400  Sat Oct 06 15:20:06 +0000 2018     0.897    0.103     0.000
# 1   -0.6597  Sat Oct 06 15:04:04 +0000 2018     0.652    0.270     0.078
# 2   -0.0762  Sat Oct 06 14:49:45 +0000 2018     0.936    0.064     0.000
# 3   -0.3412  Sat Oct 06 14:33:02 +0000 2018     0.876    0.124     0.000
# 4   -0.6486  Sat Oct 06 14:16:03 +0000 2018     0.807    0.193     0.000
#
#                Source                                               Text  \
# 0  The New York Times  Moments after the gavel sounded on the $1.4 mi...
# 1  The New York Times  During a critical point in the Vietnam War, a ...
# 2  The New York Times  White House counsel Donald F. McGahn II report...
# 3  The New York Times  "If 'Seinfeld' was a show about nothing, 'The ...
# 4  The New York Times  For months, a reputed mobster has been pursued...
#
#    Tweets Ago
# 0           1
# 1           2
# 2           3
# 3           4
# ...

# %%
# Concatenate all the DataFrames on top of each other
sentiments_pd = pd.concat([sentiments_bbc_pd, sentiments_cbs_pd, sentiments_cnn_pd, sentiments_fox_pd, 
                           sentiments_nytimes_pd], axis=0)

# Output the DataFrame to a CSV file
sentiments_pd.to_csv(output_data_file)

# Display DataFrame
sentiments_pd.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.0000  Sat Oct 06 15:32:00 +0000 2018     1.000    0.000     0.000
# 1   -0.4189  Sat Oct 06 15:11:07 +0000 2018     0.709    0.200     0.091
# 2    0.0000  Sat Oct 06 14:06:03 +0000 2018     1.000    0.000     0.000
# 3   -0.4939  Sat Oct 06 13:10:02 +0000 2018     0.789    0.211     0.000
# 4   -0.4588  Sat Oct 06 12:08:01 +0000 2018     0.769    0.231     0.000
#
#   Source                                               Text  Tweets Ago
# 0    BBC  These caves in rural Italy have been transform...           1
# 1    BBC  Please can everyone stop drinking their own ur...           2
# 2    BBC  Going, going, gone!\n\nA Banksy artwork shredd...           3
# 3    BBC  ❤️ George Shelley opens up about grief and how...           4
# 4    BBC  Footage shows hundreds of tents abandoned by p...           5

# %%
# Make the scatter plot for each news source
scatter_plot_bbc = plt.scatter(sentiments_bbc_pd["Tweets Ago"], sentiments_bbc_pd["Compound"], marker="o", s=100,
                               facecolors="lightskyblue", edgecolors="black", linewidths=1, alpha=0.9, label="BBC")

scatter_plot_cbs = plt.scatter(sentiments_cbs_pd["Tweets Ago"], sentiments_cbs_pd["Compound"], marker="o", s=100, 
                               facecolors="green", edgecolors="black", linewidths=1, alpha=0.9, label="CBS")

scatter_plot_cnn = plt.scatter(sentiments_cnn_pd["Tweets Ago"], sentiments_cnn_pd["Compound"], marker="o", s=100, 
                               facecolors="red", edgecolors="black", linewidths=1, alpha=0.9, label="CNN")

scatter_plot_fox = plt.scatter(sentiments_fox_pd["Tweets Ago"], sentiments_fox_pd["Compound"], marker="o", s=100,
                               facecolors="blue", edgecolors="black", linewidths=1, alpha=0.9, label="Fox")

scatter_plot_nytimes = plt.scatter(sentiments_nytimes_pd["Tweets Ago"], sentiments_nytimes_pd["Compound"], marker="o", s=100, 
                               facecolors="gold", edgecolors="black", linewidths=1, alpha=0.9, label="New York Times")

# Define the "now" variable using the datetime module
now = datetime.now()
now = now.strftime("(%m/%d/%y)")

# Incorporate the other graph properties
plt.ylim(-1.05, 1.05)
plt.xlim(105, -5)
plt.style.use("seaborn")

plt.title("Sentiment Analysis of Media Tweets" + " " + now)
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")

# Create a legend
plt.legend(handles=[scatter_plot_bbc, scatter_plot_cbs, scatter_plot_cnn, scatter_plot_fox, scatter_plot_nytimes], 
            loc='best', bbox_to_anchor=(1, 1), title="Media Sources")

# Save Figure
plt.savefig("SentimentAnalysisScatterPlot.png")

# Show Plot
plt.show()

# %%
# Save the news source names in an array
news_sources = ["BBC", "CBS", "CNN", "Fox", "NYT"]

# Find the overall sentiment for each news source
bbc_overall_sentiment = round(sentiments_bbc_pd["Compound"].mean(), 2)

cbs_overall_sentiment = round(sentiments_cbs_pd["Compound"].mean(), 2)

cnn_overall_sentiment = round(sentiments_cnn_pd["Compound"].mean(), 2)

fox_overall_sentiment = round(sentiments_fox_pd["Compound"].mean(), 2)

nytimes_overall_sentiment = round(sentiments_nytimes_pd["Compound"].mean(), 2)

# Save all the values in an array
overall_media_sentiment = [bbc_overall_sentiment, cbs_overall_sentiment, cnn_overall_sentiment, fox_overall_sentiment, 
                           nytimes_overall_sentiment]

# %%
# Make the bar plot for overall media sentiment
twitter_sentiment_bar_plot = plt.bar(news_sources, overall_media_sentiment, width=1, edgecolor="black", 
                                     color=("lightskyblue", "green", "red", "blue", "gold"), align="center")

# Define the "now" variable using the datetime module
now = datetime.now()
now = now.strftime("(%m/%d/%y)")

# Incorporate the other graph properties
plt.ylim(-0.12, 0.18)
plt.margins(0)
plt.grid()
plt.text(-0.1, 0.06, bbc_overall_sentiment)
plt.text(0.9, 0.15, cbs_overall_sentiment)
plt.text(1.9, 0.01, cnn_overall_sentiment)
plt.text(2.9, 0.11, fox_overall_sentiment)
plt.text(3.9, 0.01, nytimes_overall_sentiment)

plt.title("Overall Media Sentiment based on Twitter" + " " + now)
plt.xlabel("News Source")
plt.ylabel("Tweet Polarity")

# Save Figure
plt.savefig("OverallMediaSentimentBarPlot.png")

# Show Plot
plt.show()
